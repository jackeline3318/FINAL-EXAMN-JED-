# %%
import pandas as pd

# %%
a=pd.read_csv(r"C:\Users\gisse\Downloads\World University Rankings 2023 JED.csv")

# %%
a
# Out:
#       University Rank                     Name of University        Location  \
# 0                 1.0                   University of Oxford  United Kingdom
# 1                 2.0                     Harvard University   United States
# 2                 3.0                University of Cambridge  United Kingdom
# 3                 3.0                    Stanford University   United States
# 4                 5.0  Massachusetts Institute of Technology   United States
# ...               ...                                    ...             ...
# 2204              NaN                                    NaN             NaN
# 2205              NaN                                    NaN             NaN
# 2206              NaN                                    NaN             NaN
# 2207              NaN                                    NaN             NaN
# 2208              NaN                                    NaN             NaN
#
# ...

# %%
b=pd.read_csv(r"C:\Users\gisse\OneDrive\Documents\College JE.csv")

# %%
b
# Out:
#                  Name of University  Room.Board  Books  Personal  Expend  \
# 0      Abilene Christian University        3300    450      2200    7041
# 1                Adelphi University        6450    750      1500   10527
# 2                    Adrian College        3750    400      1165    8735
# 3               Agnes Scott College        5450    450       875   19016
# 4         Alaska Pacific University        4120    800      1500   10922
# ..                              ...         ...    ...       ...     ...
# 772         Worcester State College        3900    500      1200    4469
# 773               Xavier University        4960    600      1250    9189
# 774  Xavier University of Louisiana        4200    617       781    8323
# 775                 Yale University        6510    630      2115   40386
# 776    York College of Pennsylvania        3560    500      1250    4509
#
#      Total Expend   Grad.Rate
# 0            12991         60
# ...

# %%
import pandas as pd

a = pd.read_csv(r"C:\Users\gisse\OneDrive\Documents\College JE.csv")
b = pd.read_csv(r"C:\Users\gisse\Downloads\World University Rankings 2023 JED.csv")

merged_df = pd.merge(a, b, how='inner', on='Name of University')

print(merged_df)
# Out:
#                              Name of University  Room.Board  Books  Personal  \
# 0                             Boston University        6810    475      1025
# 1                              Brown University        5926    720      1100
# 2                    Carnegie Mellon University        5690    450      1250
# 3               Case Western Reserve University        4730    525      1460
# 4                           Columbia University        6664    550       300
# 5                             Dartmouth College        6070    550      1100
# 6                               Duke University        5950    625      1162
# 7                              Emory University        6000    600       870
# 8                         Georgetown University        7131    670      1700
# 9               Georgia Institute of Technology        4438    795      1164
# 10                           Harvard University        6410    500      1920
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

a = pd.read_csv(r"C:\Users\gisse\OneDrive\Documents\College JE.csv")
b = pd.read_csv(r"C:\Users\gisse\Downloads\World University Rankings 2023 JED.csv")

merged_df = pd.merge(a, b, how='inner', on='Name of University')

merged_df = merged_df.sort_values(by='University Rank', ascending=True)

plt.figure(figsize=(12, 8))
plt.bar(merged_df['Name of University'], merged_df['University Rank'], color='skyblue')
plt.xlabel('University')
plt.ylabel('Ranking')
plt.title('University Ranking')
plt.xticks(rotation=90)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

merged_df.rename(columns={'Total Expend ': 'Total Expend'}, inplace=True)

merged_df = merged_df.sort_values(by='University Rank', ascending=True)

plt.figure(figsize=(12, 8))
plt.bar(merged_df['Name of University'], merged_df['Total Expend'], color='orange')
plt.xlabel('University')
plt.ylabel('Total Expenditure')
plt.title('Total Expenditure per University')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
print("The correlation coefficient of approximately -0.44 indicates a moderate negative correlation between University Rank and Total Expenditure. This suggests that, on average, as the ranking of a university increases (lower rank number), the Total Expenditure tends to decrease.")
# Out:
# The correlation coefficient of approximately -0.44 indicates a moderate negative correlation between University Rank and Total Expenditure. This suggests that, on average, as the ranking of a university increases (lower rank number), the Total Expenditure tends to decrease.

# %%
import matplotlib.pyplot as plt

merged_df.rename(columns={'Total Expend ': 'Total Expend'}, inplace=True)

merged_df = merged_df.sort_values(by='University Rank', ascending=True)

fig, ax1 = plt.subplots(figsize=(18, 8))  

ax1.bar(merged_df['Name of University'], merged_df['Total Expend'], color='orange', label='Total Expenditure')
ax1.set_xlabel('University')
ax1.set_ylabel('Total Expenditure', color='orange')
ax1.tick_params('y', colors='orange')

ax2 = ax1.twinx()

ax2.plot(merged_df['Name of University'], merged_df['University Rank'], color='skyblue', marker='o', label='University Rank')
ax2.set_ylabel('University Rank', color='skyblue')
ax2.tick_params('y', colors='skyblue')

plt.title('Total Expenditure and University Rank per University')
ax1.set_xticklabels(merged_df['Name of University'], rotation=45, ha='right') 

fig.tight_layout()
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

plt.show()
# Out:
# C:\Users\gisse\AppData\Local\Temp\ipykernel_5448\3019086164.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(merged_df['Name of University'], rotation=45, ha='right')

# %%
import pandas as pd

merged_df.rename(columns={'Total Expend ': 'Total Expend'}, inplace=True)

merged_df = merged_df.sort_values(by='University Rank', ascending=True)

print(merged_df[['Name of University', 'University Rank', 'Total Expend']])
# Out:
#                              Name of University  University Rank  Total Expend
# 10                           Harvard University              2.0         46049
# 12        Massachusetts Institute of Technology              5.0         41841
# 16                         Princeton University              7.0         36480
# 23                              Yale University              9.0         49641
# 4                           Columbia University             11.0         38153
# 18                   University of Pennsylvania             14.0         35079
# 11                     Johns Hopkins University             15.0         64513
# 14                          New York University             24.0         29939
# 6                               Duke University             25.0         34943
# 15                      Northwestern University             26.0         34249
# 21                     University of Washington             26.0         23625
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(merged_df['Total Expend'], merged_df['University Rank'], color='blue', alpha=0.7)
plt.title('Total Expenditure vs. University Ranking')
plt.xlabel('Total Expenditure')
plt.ylabel('University Ranking')
plt.grid(True)
plt.show()

# %%
correlation_coefficient = merged_df['Total Expend'].corr(merged_df['University Rank'])
print(f"Correlation Coefficient: {correlation_coefficient}")
# Out:
# Correlation Coefficient: -0.4375259715264789

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.regplot(x='Total Expend', y='University Rank', data=merged_df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Total Expenditure vs. University Ranking with Regression Line')
plt.xlabel('Total Expenditure')
plt.ylabel('University Ranking')
plt.grid(True)
plt.show()

# %%
print("This plot states how on average, as the total expenditure increases, the university ranking tends to decrease. In other words, universities with higher rankings tend to have lower total expenditures and vice versa.")
# Out:
# This plot states how on average, as the total expenditure increases, the university ranking tends to decrease. In other words, universities with higher rankings tend to have lower total expenditures and vice versa.

# %%
print("I feel like it could be a reasonable way depending on the personal goal, I feel like correlation does not imply causation. It's crucial to consider the specific context of each university and understand that correlation doesn't establish a direct cause-and-effect relationship. Some universities might prioritize efficient resource utilization, while others may have higher expenditures for reasons such as extensive research programs, etc")
# Out:
# I feel like it could be a reasonable way depending on the personal goal, I feel like correlation does not imply causation. It's crucial to consider the specific context of each university and understand that correlation doesn't establish a direct cause-and-effect relationship. Some universities might prioritize efficient resource utilization, while others may have higher expenditures for reasons such as extensive research programs, etc
